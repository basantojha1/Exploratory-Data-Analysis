# %%
# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
from matplotlib import rcParams # used to customize the apprence of your plot
import seaborn as sns

# applying styling
plt.style.use('ggplot')
rcParams['figure.figsize'] = (12, 6)

# using Sklearn to import a dataset
from sklearn.datasets import load_wine

# %%
# Loading wine dataset
wine = load_wine()

# converting the dataset to pandas dataframe
df = pd.DataFrame(data = wine.data, columns = wine.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
# creating target column
df['target'] = wine.target

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
# checking column names
df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.tail()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
# ...

# %%
df.shape
# Out:
# (178, 14)

# %%
df.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# target                            int32
# dtype: object

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
# Checks for the sum of number of null values in each column
df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %%
# Checking for any duplicates in the row
df.duplicated().sum()
# Out:
# 0

# %%
# renaming
df.rename(columns = {'od280/od315_of_diluted_wines':'protein_concentration'}, inplace = True)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    protein_concentration  proline  target
# ...

# %% [markdown]
# # Univariate Analysis

# %%
df.target.value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: target, dtype: int64

# %%
# We can also check in percentage instead of numbers by passing normalize = True
df.target.value_counts(normalize = True)
# Out:
# 1    0.398876
# 0    0.331461
# 2    0.269663
# Name: target, dtype: float64

# %%
# Plotting a data using matplotlib library
df.target.value_counts().plot(kind='bar')
plt.title('Value count of Target variable')
plt.xlabel('wine type')
plt.ylabel('count')
plt.show()

# %%
df.magnesium.describe()
# Out:
# count    178.000000
# mean      99.741573
# std       14.282484
# min       70.000000
# 25%       88.000000
# 50%       98.000000
# 75%      107.000000
# max      162.000000
# Name: magnesium, dtype: float64

# %%
df.magnesium.hist()
plt.title('Distribution of Magnesium')
# Out:
# Text(0.5, 1.0, 'Distribution of Magnesium')

# %%
# Evaluating kurtosis and asymmetry

print(f"Skewness: {df['magnesium'].skew()}")
print(f"Kurtosis: {df['magnesium'].kurt()}")
# Out:
# Skewness: 1.098191054755161
# Kurtosis: 2.1049913235905557

# %%
# Doing it another way
import scipy.stats as stats
skewness = stats.skew(df['magnesium'])
kurtosis = stats.kurtosis(df['magnesium'])
print(skewness)
print(kurtosis)
# Out:
# 1.088914887210701
# 2.0128060084773907

# %%
# exploring relationship between variables
# Seaborn pairplot (scatter plot)
sns.pairplot(df)

# %%
# Creating box plot using seaborn library
sns.catplot(x = 'target', y = 'alcohol', data = df, kind = 'box', aspect=1.5)
plt.title('Boxplot for target vs alcohol')
plt.show()

# %%
sns.catplot(x='target', y='flavanoids', data=df, kind='box', aspect=1.5)
plt.title('Boxplot for target vs flavanoids')
plt.show()

# %%
sns.catplot(x='target', y='color_intensity', data=df, kind='box', aspect=1.5)
plt.title('Boxplot for target vs color_intensity')
plt.show()

# %%
sns.catplot(x='target', y='proline', data=df, kind='box', aspect=1.5)
plt.title('Boxplot for target vs proline')
plt.show()

# %%
# creating scatter plot to visualize the points belinging to different wine class
sns.scatterplot(x='proline', y='flavanoids', hue='target', data=df, palette='Dark2', s=80)
plt.title('Relationship between prolin, flavanoidsand target')
plt.show()

# %%
# ScatterPlot
sns.scatterplot(x='alcohol', y='color_intensity', hue='target', data=df, palette='Dark2', s=80)
plt.title('Relationship Between alcohol, color_intensity and target')
plt.show()

# %%
# Heatmap creation
corrmat = df.corr()

# %%
heatmap = sns.heatmap(corrmat,
                      cbar=True,
                      square=True,
                      annot=True,
                      yticklabels = df.columns,
                      xticklabels = df.columns,
                      cmap='Spectral_r'
                     )
